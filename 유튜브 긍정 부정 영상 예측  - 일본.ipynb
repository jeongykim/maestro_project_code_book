# %%
import pandas as pd
data = pd.read_csv('JPvideos.csv')
data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
data['time'] = data.publish_time.str.slice(11,19)

# %%
data.shape
# Out:
# (20523, 17)

# %%
data
# Out:
#           video_id trending_date  \
# 0      5ugKfHgsmYw      18.07.02
# 1      ohObafdd34Y      18.07.02
# 2      aBr2kKAHN6M      18.07.02
# 3      5wNnwChvmsQ      18.07.02
# 4      B7J47qFvdsk      18.07.02
# ...            ...           ...
# 20518  GuWCkLnCMOo      18.14.06
# 20519  nOUlB0i2MaA      18.14.06
# 20520  4cRanIowkTE      18.14.06
# 20521  oLtWIVBVoS8      18.14.06
# 20522  2IEWv23oa9E      18.14.06
#
#                                                    title  \
# 0                                     陸自ヘリ、垂直に落下＝路上の車が撮影
# 1                                 イッテQ お祭り男宮川×手越 巨大ブランコ②
# 2                                  Live Views of Starman
# 3                             東京ディズニーリゾートの元キャストが暴露した秘密5選
# 4              榮倉奈々、衝撃の死んだふり！映画『家に帰ると妻が必ず死んだふりをしています。』特報
# ...                                                  ...
# 20518  หนึ่งด้าวฟ้าเดียว NeungDaoFahDeaw EP.15 ตอนที่...
# 20519  2018 국민의 선택 - 선거방송 '왕의 귀환' 12시간 연속 생중계! (풀영상) ...
# 20520            元FBIエージェントが教える、200％人を引き付けるようになるコツ、トップ10
# 20521     日本×パラグアイ徹底分析&スペイン代表監督解任事件を解説【トークtheフットボール】#683
# 20522                             エサのコオロギに夢中で二本足で立つカメレオン
#
#                      channel_title  category_id              publish_time  \
# 0                       時事通信映像センター           25  2018-02-06T03:04:37.000Z
# 1             神谷えりな Kamiya Erina 2            1  2018-02-06T04:01:56.000Z
# 2                           SpaceX           28  2018-02-06T21:38:22.000Z
# 3                          アシタノワダイ           25  2018-02-06T06:08:49.000Z
# 4                          シネマトゥデイ            1  2018-02-06T02:30:00.000Z
# ...                            ...          ...                       ...
# 20518                  Ch3Thailand           24  2018-06-13T17:00:01.000Z
# 20519                       SBS 뉴스           25  2018-06-13T19:10:31.000Z
# 20520  ブライトサイド | Bright Side Japan           26  2018-06-13T14:00:02.000Z
# 20521          Leo the football TV           17  2018-06-13T13:56:47.000Z
# 20522                    釣りよかHOUSE           24  2018-06-13T09:00:00.000Z
#
#                                                     tags    views   likes  \
# 0      事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...   188085     591
# 1                                                 [none]    90929     442
# 2                                                 [none]  6408303  165892
# 3                                                アシタノワダイ    96255    1165
# 4                                                 [none]   108408    1336
# ...                                                  ...      ...     ...
# 20518  หนึ่งด้าวฟ้าเดียว|"NeungDaoFahDeaw"|"เจมส์ จิร...    81321     321
# 20519  뉴스|"NEWS"|"news"|"SBS"|"sbs"|"SBS NEWS"|"SBS8N...   433188       0
# 20520  人々を魅了する方法|"魅力的になるには"|"成功の秘訣"|"簡単なトリック"|"人から好かれ...    39235    1194
# 20521  W杯|"ワールドカップ"|"蹴球"|"思想家"|"ラジオ"|"ナポリ"|"ライプツィヒ"|"...    49900     431
# 20522                    よーらい|"佐賀よかでしょう"|"釣りよかでしょう"|"釣り"    46265     816
#
#        dislikes  comment_count  \
# 0           189              0
# 1            88            174
# 2          2331           3006
# 3           277            545
# 4            74            201
# ...         ...            ...
# 20518        17             61
# 20519         0            175
# 20520        27             46
# 20521        66            336
# 20522        40             59
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg               True
# 1      https://i.ytimg.com/vi/ohObafdd34Y/default.jpg              False
# 2      https://i.ytimg.com/vi/aBr2kKAHN6M/default.jpg              False
# 3      https://i.ytimg.com/vi/5wNnwChvmsQ/default.jpg              False
# 4      https://i.ytimg.com/vi/B7J47qFvdsk/default.jpg              False
# ...                                               ...                ...
# 20518  https://i.ytimg.com/vi/GuWCkLnCMOo/default.jpg              False
# 20519  https://i.ytimg.com/vi/nOUlB0i2MaA/default.jpg              False
# 20520  https://i.ytimg.com/vi/4cRanIowkTE/default.jpg              False
# 20521  https://i.ytimg.com/vi/oLtWIVBVoS8/default.jpg              False
# 20522  https://i.ytimg.com/vi/2IEWv23oa9E/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 20518             False                   False
# 20519              True                   False
# 20520             False                   False
# 20521             False                   False
# 20522             False                   False
#
#                                              description      time
# 0      佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...  03:04:37
# 1                                                    NaN  04:01:56
# 2                                                    NaN  21:38:22
# 3      東京ディズニーリゾートの元キャストが暴露した秘密5選\n\nかたまりクリエイトさま\n【検証...  06:08:49
# 4      家に帰ってきたサラリーマンのじゅん（安田顕）は、玄関で血を出して倒れている妻ちえ（榮倉奈々）...  02:30:00
# ...                                                  ...       ...
# 20518  หลังจบละครทางหน้าจอทีวี สามารถรับชมได้อีกครั้ง...  17:00:01
# 20519  '선거방송의 명가' SBS가 온다! SBS가 제 7회 전국동시지방선거(6·13 지방...  19:10:31
# 20520  元FBIエージェント、ジャック･シェーファー医師が明かす、人に200％魅力的に見せるトリック...  14:00:02
# 20521  「２０１８Ｗ杯ロシア大会日本代表戦ライヴイベント」日本代表のグループリーグ３試合をLeo t...  13:56:47
# 20522  使用した物https://amzn.to/2JwOEPGメインチャンネル　釣りよかでしょうh...  09:00:00
#
# [20523 rows x 17 columns]

# %% [markdown]
# # 조회수 0회인 열 제외 (영상이 제거 되면 조회수가 0으로 기록)
# # 트랜딩 업데이트가 되어 중복되는 title 제거

# %%
data2 = data[data['views']!=0]
data3 = data2.drop_duplicates("title")

# %%
data3.shape
# Out:
# (13087, 17)

# %%
data3.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'time'],
#       dtype='object')

# %%
data3 = data3[['views','likes', 'dislikes', 'comment_count','tags','time','category_id','comments_disabled','ratings_disabled']]

# %%
data3
# Out:
#          views   likes  dislikes  comment_count  \
# 0       188085     591       189              0
# 1        90929     442        88            174
# 2      6408303  165892      2331           3006
# 3        96255    1165       277            545
# 4       108408    1336        74            201
# ...        ...     ...       ...            ...
# 20467    35735    1959         9            311
# 20468    38214     551        75             90
# 20469   640996   10105      1034           1961
# 20470   134920    3766       180            408
# 20472    17237     369        29             93
#
#                                                     tags      time  \
# 0      事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  03:04:37
# 1                                                 [none]  04:01:56
# 2                                                 [none]  21:38:22
# 3                                                アシタノワダイ  06:08:49
# 4                                                 [none]  02:30:00
# ...                                                  ...       ...
# 20467                       ピアノ|"piano"|"marasy8"|"まらしぃ"  10:46:36
# 20468  ポケモンgo|"ポケモン"|"GO"|"はつだ"|"はっちゃんねる"|"実況"|"攻略"|"...  10:00:00
# 20469                                             [none]  10:33:56
# 20470  nepali comedy video|"nepali comedy serial"|"ne...  14:15:01
# 20472  おこぷれ|"おこさまぷれ〜と。"|"YouTuber"|"JK"|"女子高生"|"おこさまぷ...  11:00:03
#
#        category_id  comments_disabled  ratings_disabled
# 0               25               True             False
# 1                1              False             False
# 2               28              False             False
# 3               25              False             False
# 4                1              False             False
# ...            ...                ...               ...
# 20467           10              False             False
# 20468           20              False             False
# 20469           29              False             False
# 20470           23              False             False
# 20472           24              False             False
#
# [13087 rows x 9 columns]

# %% [markdown]
# # 댓글 막기, 평가 내린 것 안보이게 막기 범주 0,1 변환

# %%
data3['comments_block'] = data3.comments_disabled.replace({False, True},{0, 1})
#data3.comments_disabled.replace(True, 1)

# %%
data3['ratings_block'] = data3.ratings_disabled.replace({False, True},{0, 1})

# %% [markdown]
# # 출간 시간대 변수 변환

# %%
data3.time
# Out:
# 0        03:04:37
# 1        04:01:56
# 2        21:38:22
# 3        06:08:49
# 4        02:30:00
#            ...
# 20467    10:46:36
# 20468    10:00:00
# 20469    10:33:56
# 20470    14:15:01
# 20472    11:00:03
# Name: time, Length: 13087, dtype: object

# %%
data3['pub_time'] = pd.to_numeric(data3.time.str.slice(0,2))

# %%
data3.dtypes # 문자열 파일 숫자형으로 변환 완료
# Out:
# views                 int64
# likes                 int64
# dislikes              int64
# comment_count         int64
# tags                 object
# time                 object
# category_id           int64
# comments_disabled      bool
# ratings_disabled       bool
# comments_block        int64
# ratings_block         int64
# pub_time              int64
# dtype: object

# %% [markdown]
# # 태그 유무 전처리

# %%
data4 = data3[data3.tags!='[none]']

# %%
data4['tag_yn'] = 1
# Out:
# <ipython-input-16-039ff464554b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['tag_yn'] = 1

# %%
data4
# Out:
#         views  likes  dislikes  comment_count  \
# 0      188085    591       189              0
# 3       96255   1165       277            545
# 5      193593      0         0             53
# 9      105112   1547       540            499
# 11     245032   3020       222              0
# ...       ...    ...       ...            ...
# 20465   46409   5389        22           1150
# 20467   35735   1959         9            311
# 20468   38214    551        75             90
# 20470  134920   3766       180            408
# 20472   17237    369        29             93
#
#                                                     tags      time  \
# 0      事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  03:04:37
# 3                                                アシタノワダイ  06:08:49
# 5         有賀さつき|"八木亜希子"|"河野景子"|"貴乃花"|"三宅"|"ありがさつき"|"和田圭"  03:27:10
# 9      卵|"玉子"|"TKG"|"醤油"|"たまごかけご飯"|"卵かけご飯"|"Recipe (L...  06:30:00
# 11     DHC|"DHCテレビ"|"DHCテレビジョン"|"虎ノ門"|"ニュース"|"NEWS"|"...  01:25:07
# ...                                                  ...       ...
# 20465  TokinoSora|"ときのそら"|"そら"|"そらちゃん"|"時乃そら"|"そらチャンネ...  10:16:07
# 20467                       ピアノ|"piano"|"marasy8"|"まらしぃ"  10:46:36
# 20468  ポケモンgo|"ポケモン"|"GO"|"はつだ"|"はっちゃんねる"|"実況"|"攻略"|"...  10:00:00
# 20470  nepali comedy video|"nepali comedy serial"|"ne...  14:15:01
# 20472  おこぷれ|"おこさまぷれ〜と。"|"YouTuber"|"JK"|"女子高生"|"おこさまぷ...  11:00:03
#
#        category_id  comments_disabled  ratings_disabled  comments_block  \
# 0               25               True             False               1
# 3               25              False             False               0
# 5               22              False              True               0
# 9               19              False             False               0
# 11              24               True             False               1
# ...            ...                ...               ...             ...
# 20465           24              False             False               0
# 20467           10              False             False               0
# 20468           20              False             False               0
# 20470           23              False             False               0
# 20472           24              False             False               0
#
#        ratings_block  pub_time  tag_yn
# 0                  0         3       1
# 3                  0         6       1
# 5                  1         3       1
# 9                  0         6       1
# 11                 0         1       1
# ...              ...       ...     ...
# 20465              0        10       1
# 20467              0        10       1
# 20468              0        10       1
# 20470              0        14       1
# 20472              0        11       1
#
# [11041 rows x 13 columns]

# %%
data5 = data3[data3.tags=='[none]']

# %%
data5['tag_yn'] = 0
# Out:
# <ipython-input-19-abf45856b82c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['tag_yn'] = 0

# %%
data5
# Out:
#          views   likes  dislikes  comment_count    tags      time  \
# 1        90929     442        88            174  [none]  04:01:56
# 2      6408303  165892      2331           3006  [none]  21:38:22
# 4       108408    1336        74            201  [none]  02:30:00
# 6        55465     189       339            800  [none]  05:31:33
# 7        66272      51       167            164  [none]  07:01:29
# ...        ...     ...       ...            ...     ...       ...
# 20418    50804    4157        39            286  [none]  15:00:01
# 20419    46910    2225        33             31  [none]  14:47:35
# 20432    26847      84        20              0  [none]  12:37:56
# 20451   111141     267        39            552  [none]  12:58:59
# 20469   640996   10105      1034           1961  [none]  10:33:56
#
#        category_id  comments_disabled  ratings_disabled  comments_block  \
# 1                1              False             False               0
# 2               28              False             False               0
# 4                1              False             False               0
# 6               22              False             False               0
# 7               23              False             False               0
# ...            ...                ...               ...             ...
# 20418           10              False             False               0
# 20419           24              False             False               0
# 20432           17               True             False               1
# 20451           17              False             False               0
# 20469           29              False             False               0
#
#        ratings_block  pub_time  tag_yn
# 1                  0         4       0
# 2                  0        21       0
# 4                  0         2       0
# 6                  0         5       0
# 7                  0         7       0
# ...              ...       ...     ...
# 20418              0        15       0
# 20419              0        14       0
# 20432              0        12       0
# 20451              0        12       0
# 20469              0        10       0
#
# [2046 rows x 13 columns]

# %%
data6 = pd.concat([data4, data5])

# %%
data6
# Out:
#         views  likes  dislikes  comment_count  \
# 0      188085    591       189              0
# 3       96255   1165       277            545
# 5      193593      0         0             53
# 9      105112   1547       540            499
# 11     245032   3020       222              0
# ...       ...    ...       ...            ...
# 20418   50804   4157        39            286
# 20419   46910   2225        33             31
# 20432   26847     84        20              0
# 20451  111141    267        39            552
# 20469  640996  10105      1034           1961
#
#                                                     tags      time  \
# 0      事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  03:04:37
# 3                                                アシタノワダイ  06:08:49
# 5         有賀さつき|"八木亜希子"|"河野景子"|"貴乃花"|"三宅"|"ありがさつき"|"和田圭"  03:27:10
# 9      卵|"玉子"|"TKG"|"醤油"|"たまごかけご飯"|"卵かけご飯"|"Recipe (L...  06:30:00
# 11     DHC|"DHCテレビ"|"DHCテレビジョン"|"虎ノ門"|"ニュース"|"NEWS"|"...  01:25:07
# ...                                                  ...       ...
# 20418                                             [none]  15:00:01
# 20419                                             [none]  14:47:35
# 20432                                             [none]  12:37:56
# 20451                                             [none]  12:58:59
# 20469                                             [none]  10:33:56
#
#        category_id  comments_disabled  ratings_disabled  comments_block  \
# 0               25               True             False               1
# 3               25              False             False               0
# 5               22              False              True               0
# 9               19              False             False               0
# 11              24               True             False               1
# ...            ...                ...               ...             ...
# 20418           10              False             False               0
# 20419           24              False             False               0
# 20432           17               True             False               1
# 20451           17              False             False               0
# 20469           29              False             False               0
#
#        ratings_block  pub_time  tag_yn
# 0                  0         3       1
# 3                  0         6       1
# 5                  1         3       1
# 9                  0         6       1
# 11                 0         1       1
# ...              ...       ...     ...
# 20418              0        15       0
# 20419              0        14       0
# 20432              0        12       0
# 20451              0        12       0
# 20469              0        10       0
#
# [13087 rows x 13 columns]

# %% [markdown]
# # 만들고 필요한 변수들만 가져오기 1

# %%
data6 = data6[['views','likes','dislikes','comment_count','category_id','comments_block','ratings_block','pub_time','tag_yn']]

# %%
data6.columns
# Out:
# Index(['views', 'likes', 'dislikes', 'comment_count', 'category_id',
#        'comments_block', 'ratings_block', 'pub_time', 'tag_yn'],
#       dtype='object')

# %%
data6 = data6[data6.likes!=0]
data6 = data6[data6.dislikes!=0]

# %%
data6.shape
# Out:
# (11945, 9)

# %% [markdown]
# # 긍정 <= 부정 타겟 생성  부정이 높거나 같으면 1 낮으면 긍정

# %%
data6['rate']= data6.likes/data6.dislikes

# %%
data6.rate.describe()
# Out:
# count    11945.000000
# mean        39.632377
# std         82.652137
# min          0.015493
# 25%          5.908397
# 50%         15.000000
# 75%         38.888889
# max       1935.000000
# Name: rate, dtype: float64

# %% [markdown]
# # 긍정 보통 부정 target 선정

# %%
data7 = data6[data6.rate>=38]

# %%
data7['Target'] = '긍정'
# Out:
# <ipython-input-31-6ddd65f5915f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data7['Target'] = '긍정'

# %%
data8 = data6[(data6.rate < 38) & (data6.rate>=3.5)]

# %%
data8['Target'] = '보통'
# Out:
# <ipython-input-33-1a834e072575>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['Target'] = '보통'

# %%
data9 = data6[data6.rate < 3.5]

# %%
data9['Target']='부정'
# Out:
# <ipython-input-35-aa96bfc9c773>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data9['Target']='부정'

# %%
data7.shape,data8.shape,data9.shape
# Out:
# ((3040, 11), (7097, 11), (1808, 11))

# %%
data7.shape[0]+data8.shape[0]+data9.shape[0]
# Out:
# 11945

# %%
data10 = pd.concat([data7, data8, data9])

# %%
data10
# Out:
#           views   likes  dislikes  comment_count  category_id  comments_block  \
# 13       120824    5699        89            699           26               0
# 23        12637     288         3             21            2               0
# 25     12908071  290084      5326          26863           24               0
# 137      223565    1714        35            154           24               0
# 139       88496    5714        36            266           24               0
# ...         ...     ...       ...            ...          ...             ...
# 18604    362505     751       339            622           22               0
# 18645     22337     181        77             49           24               0
# 18780     62502     167        58            166           25               0
# 19551    155271     288       635           1912           17               0
# 19965     16679     201        72             99           24               0
#
#        ratings_block  pub_time  tag_yn        rate Target
# 13                 0         8       1   64.033708     긍정
# 23                 0         0       1   96.000000     긍정
# 25                 0         2       1   54.465640     긍정
# 137                0         8       1   48.971429     긍정
# 139                0         3       1  158.722222     긍정
# ...              ...       ...     ...         ...    ...
# 18604              0         8       0    2.215339     부정
# 18645              0        21       0    2.350649     부정
# 18780              0        23       0    2.879310     부정
# 19551              0        23       0    0.453543     부정
# 19965              0         8       0    2.791667     부정
#
# [11945 rows x 11 columns]

# %%
data6.shape
# Out:
# (11945, 10)

# %%
data10.Target.value_counts()
# Out:
# 보통    7097
# 긍정    3040
# 부정    1808
# Name: Target, dtype: int64

# %%
data10
# Out:
#           views   likes  dislikes  comment_count  category_id  comments_block  \
# 13       120824    5699        89            699           26               0
# 23        12637     288         3             21            2               0
# 25     12908071  290084      5326          26863           24               0
# 137      223565    1714        35            154           24               0
# 139       88496    5714        36            266           24               0
# ...         ...     ...       ...            ...          ...             ...
# 18604    362505     751       339            622           22               0
# 18645     22337     181        77             49           24               0
# 18780     62502     167        58            166           25               0
# 19551    155271     288       635           1912           17               0
# 19965     16679     201        72             99           24               0
#
#        ratings_block  pub_time  tag_yn        rate Target
# 13                 0         8       1   64.033708     긍정
# 23                 0         0       1   96.000000     긍정
# 25                 0         2       1   54.465640     긍정
# 137                0         8       1   48.971429     긍정
# 139                0         3       1  158.722222     긍정
# ...              ...       ...     ...         ...    ...
# 18604              0         8       0    2.215339     부정
# 18645              0        21       0    2.350649     부정
# 18780              0        23       0    2.879310     부정
# 19551              0        23       0    0.453543     부정
# 19965              0         8       0    2.791667     부정
#
# [11945 rows x 11 columns]

# %%
data10 = data10.rename(columns={'views':'view_count','category_id':'categoryId'})

# %%
df = data10[['view_count','comment_count','categoryId','comments_block','ratings_block','pub_time','tag_yn','Target']]

# %%
df
# Out:
#        view_count  comment_count  categoryId  comments_block  ratings_block  \
# 13         120824            699          26               0              0
# 23          12637             21           2               0              0
# 25       12908071          26863          24               0              0
# 137        223565            154          24               0              0
# 139         88496            266          24               0              0
# ...           ...            ...         ...             ...            ...
# 18604      362505            622          22               0              0
# 18645       22337             49          24               0              0
# 18780       62502            166          25               0              0
# 19551      155271           1912          17               0              0
# 19965       16679             99          24               0              0
#
#        pub_time  tag_yn Target
# 13            8       1     긍정
# 23            0       1     긍정
# 25            2       1     긍정
# 137           8       1     긍정
# 139           3       1     긍정
# ...         ...     ...    ...
# 18604         8       0     부정
# 18645        21       0     부정
# 18780        23       0     부정
# 19551        23       0     부정
# 19965         8       0     부정
#
# [11945 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(df.iloc[:,0:7], df.iloc[:,7:8], random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((8958, 7), (2987, 7))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr.score(X_train, y_train),lr.score(X_test, y_test)
# Out:
# C:\Users\CPB06GameN\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# (0.5951105157401205, 0.6036156678942083)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=229)
knn.fit(X_train,y_train)
knn.score(X_train, y_train), knn.score(X_test, y_test)
# Out:
# <ipython-input-53-a1bd534a785b>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(X_train,y_train)
# (0.5916499218575575, 0.601606963508537)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state=283)
tree.fit(X_train, y_train)
tree.score(X_train, y_train) , tree.score(X_test, y_test)
# Out:
# (1.0, 0.547706729159692)

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=70,random_state=3)
forest.fit(X_train,y_train)
forest.score(X_train, y_train) , forest.score(X_test, y_test)
# Out:
# <ipython-input-55-5c093a678eb4>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train,y_train)
# (0.9997767358785443, 0.6360897221292267)

# %%
df.to_csv("Japen.csv")
