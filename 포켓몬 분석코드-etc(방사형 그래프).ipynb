# %%
import pandas as pd
pok = pd.read_csv("pokemondata(real-8세대 제외).csv", encoding="latin")
pok
# Out:
#      Unnamed: 0  pokedex_number           name  generation         status  \
# 0             0               1      Bulbasaur           1         Normal
# 1             1               2        Ivysaur           1         Normal
# 2             2               3       Venusaur           1         Normal
# 3             3               3  Mega Venusaur           1         Normal
# 4             4               4     Charmander           1         Normal
# ..          ...             ...            ...         ...            ...
# 935         935             805      Stakataka           7  Sub Legendary
# 936         936             806    Blacephalon           7  Sub Legendary
# 937         937             807        Zeraora           7       Mythical
# 938         938             808         Meltan           7       Mythical
# 939         939             809       Melmetal           7       Mythical
#
#           species  type_number    type_1  type_2  height_m  ...  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
categories = ['hp','attack','defense','sp_attack','sp_defense','speed']
categories = [*categories, categories[0]]
categories
# Out:
# ['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'hp']

# %%
pok2 = pok[["name",'hp','attack','defense','sp_attack','sp_defense','speed']]
pok2.head()
# Out:
#             name  hp  attack  defense  sp_attack  sp_defense  speed
# 0      Bulbasaur  45      49       49         65          65     45
# 1        Ivysaur  60      62       63         80          80     60
# 2       Venusaur  80      82       83        100         100     80
# 3  Mega Venusaur  80     100      123        122         120     80
# 4     Charmander  39      52       43         60          50     65

# %%
A = input('원하는 포켓몬을 입력하세요:')
pok_status = pok2[pok2['name'].isin([A])].iloc[:,[1,2,3,4,5,6]]
# Out:
# 원하는 포켓몬을 입력하세요:Pikachu

# %%
B = input('원하는 포켓몬을 입력하세요:')
pok_status2 = np.array(pok2[pok2['name'].isin([B])].iloc[:,[1,2,3,4,5,6]])
# Out:
# 원하는 포켓몬을 입력하세요:Raichu

# %%
C = input('원하는 포켓몬을 입력하세요:')
pok_status3 = np.array(pok2[pok2['name'].isin([C])].iloc[:,[1,2,3,4,5,6]])
# Out:
# 원하는 포켓몬을 입력하세요:Venusaur

# %%
pok_status = sum(np.array(pok_status).tolist(),[])
pok_status = [*pok_status,pok_status[0]]
pok_status2 = sum(np.array(pok_status2).tolist(),[])
pok_status2 = [*pok_status2,pok_status2[0]]
# pok_status3 = sum(np.array(pok_status3).tolist(),[])
# pok_status3 = [*pok_status3,pok_status3[0]]
# pok_status

# %%
label_loc = np.linspace(start=0, stop=2*np.pi,num=len(pok_status))
label_loc
# Out:
# array([0.        , 1.04719755, 2.0943951 , 3.14159265, 4.1887902 ,
#        5.23598776, 6.28318531])

# %%
pok_status
# Out:
# [20, 40, 15, 35, 35, 60, 20]

# %%
plt.figure(figsize=(8,8))
ax = plt.subplot(polar=True)
plt.xticks(label_loc, labels=categories, fontsize=13)
ax.plot(label_loc,pok_status, label=A,linestyle='dashdot',color='gold', marker='o')
ax.fill(label_loc,pok_status, color='gold',alpha=0.2)
ax.plot(label_loc,pok_status2, label=B,linestyle='dashdot',color='orange',marker='o')
ax.fill(label_loc,pok_status2, color='orange',alpha=0.1)
# ax.plot(label_loc,pok_status3, label=C,linestyle='dashdot',color='skyblue')
# ax.fill(label_loc,pok_status3, color='skyblue',alpha=0.3)        
ax.legend(loc='center')
plt.show()
#plum
